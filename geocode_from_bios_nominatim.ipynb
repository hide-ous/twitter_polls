# %%
import json
import os
from functools import partial

import pandas as pd
from backoff import on_exception, expo
from geopy import Photon
from geopy.exc import GeocoderUnavailable, GeocoderTimedOut
from geopy.geocoders import Nominatim
from ratelimit import limits, sleep_and_retry
from tqdm import tqdm
import pickle

# %%
DUMMY_LOCATION_STRS = ["Berlin, Deutschland",
"France",
"Paris et plein Centre",
"Punjab, Pakistan",
"South Africa",
"Boulder, Colorado",
"NONE",
"London",
"United States",
"Ethiopia",
"Ethiopia",
"TΧ",
"NONE",
"Paris, Mulhouse, sur la route",
"London",
"Barcelona",
"Liverpool",
"Bay Area, CA"]

# %%
DATA_PATH = 'data'

# %%
# @sleep_and_retry
# @on_exception(expo, GeocoderTimedOut, max_tries=8)
# @limits(calls=1, period=1)
def get_location(location_str, geolocator, **kwargs):
    try:
        return geolocator.geocode(location_str, **kwargs)
    except GeocoderUnavailable as e:
        return None

# %%
# @sleep_and_retry
# @on_exception(expo, GeocoderTimedOut, max_tries=8)
# @limits(calls=1, period=1)
def reverse_location(location_obj, geolocator, **kwargs):
    try:
        coords = ",".join((location_obj.raw['lat'], location_obj.raw['lon']))
    except AttributeError as e:
        return None
    try:
        return geolocator.reverse(coords, **kwargs)
    except GeocoderUnavailable as e:
        return None

# %%
def read_locations(users_path=None):
    """
    reads the input data
    :return: a dataframe with a column `location_str` containing the description of the location
    """
    if users_path is None:
        return pd.DataFrame(DUMMY_LOCATION_STRS, columns=['location_str'], index=range(len(DUMMY_LOCATION_STRS)))
    else:
        return pd.read_json(os.path.join(DATA_PATH, users_path),
                            lines=True
                            ).rename(columns={'location':'location_str'}
                                     ).set_index('id').dropna(subset=['location_str'])

        # with open(users_path, encoding='utf8') as f:
        #     # users = {k:v for l in f for k, v in json.loads(l).items()}
        #
        #     users = pd.concat(
        #         pd.DataFrame([dict(follower, **{'follows':pollster}) for follower in followers])
        #         for l in f for pollster, followers in json.loads(l).items()
        #     )
        # return users

# %%
# users = read_locations(os.path.join(DATA_PATH, 'followers_rehydrated.jsonl'))
# # pd.read_json('data/followers_rehydrated.jsonl', lines=True, nrows=100)
# users=pd.read_json('data/followers_rehydrated.jsonl',
#                             lines=True
#                             ).rename(columns={'location':'location_str'}
#                                      ).set_index('id').dropna(subset=['location_str'])

# %%
followers = list()
with open('data/followers_rehydrated.jsonl') as f:
    for l in f:
        try:
            followers.append(json.loads(l))
        except:
            print(f"can't parse {l.strip()}")

# %%
users = pd.DataFrame(followers).rename(columns={'location':'location_str'}
                                     ).set_index('id').dropna(subset=['location_str'])

# %%
del followers

# %%
users.head(2)
# Out:
#                         name  \
# id
# 3070230547           京犬@ポケモン
# 1454016580874997763  Gift So
#
#                                                      profile_image_url  \
# id
# 3070230547           https://pbs.twimg.com/profile_images/852969926...
# 1454016580874997763  https://pbs.twimg.com/profile_images/145401840...
#
#                                     location_str  \
# id
# 3070230547                                    日本
# 1454016580874997763  Republic of the Philippines
#
#                                                         public_metrics  \
# id
# 3070230547           {'followers_count': 2422, 'following_count': 2...
# 1454016580874997763  {'followers_count': 6, 'following_count': 93, ...
#
#                      protected     pinned_tweet_id         username  \
# id
# 3070230547               False  799393599917957120         inu_2525
# 1454016580874997763      False                 NaN  hermajestygifty
#
#                                                            description  \
# id
# 3070230547                                   ゲーム垢用。仲良ししてくださいね！ #モンハン女子
# 1454016580874997763  Unwrap the 🎁.                                 ...
#
#                                    created_at  verified  \
# id
# 3070230547           2015-03-09T19:15:39.000Z     False
# 1454016580874997763  2021-10-29T09:26:00.000Z     False
#
#                                                               entities  url  \
# id
# 3070230547           {'description': {'hashtags': [{'start': 18, 'e...  NaN
# 1454016580874997763                                                NaN  NaN
#
#                     withheld
# id
# 3070230547               NaN
# 1454016580874997763      NaN

# %%
# read the data
# locations = read_locations(os.path.join(DATA_PATH, 'followers_rehydrated.jsonl'))
locations = users
# initialize the geolocator service
# geolocator = Nominatim(user_agent="twitter_poll_bio_geocoding_v0.0.1",
#                        domain='localhost:8080/nominatim', scheme='http')
# geolocator = Nominatim(user_agent="twitter_poll_bio_geocoding_v0.0.1",
#                        domain='localhost:8080', scheme='http')
geolocator = Photon(user_agent="twitter_poll_bio_geocoding_v0.0.1",
                       domain='localhost:2322', scheme='http')

# %%
unique_locations = set(locations.location_str.unique())

# %%
len(locations)
# Out:
# 6003783

# %%
del locations

# %%
resolved = dict()
tested = set()
timed_out = set()
excepted = set()

# %%
for location in tqdm(unique_locations):
    if location in tested:
        continue
    try:
        resolved[location] = get_location(location, geolocator)
    except GeocoderTimedOut as e:
        timed_out.add(location)
    except Exception as e:
        excepted.add(location)
    finally:
        tested.add(location)
# Out:
#   0%|          | 1118/1131028 [00:51<14:21:19, 21.86it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 5
#       3     continue
#       4 try:
# ----> 5     resolved[location] = get_location(location, geolocator)
#       6 except GeocoderTimedOut as e:
#       7     timed_out.add(location)
#
# Cell In[4], line 6, in get_location(location_str, geolocator, **kwargs)
#       4 def get_location(location_str, geolocator, **kwargs):
#       5     try:
# ----> 6         return geolocator.geocode(location_str, **kwargs)
#       7     except GeocoderUnavailable as e:
#       8         return None
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\geopy\geocoders\photon.py:166, in Photon.geocode(self, query, exactly_one, timeout, location_bias, language, limit, osm_tag, bbox)
#     164 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     165 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 166 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     366 try:
#     367     if is_json:
# --> 368         result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369     else:
#     370         result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\geopy\adapters.py:447, in RequestsAdapter.get_json(self, url, timeout, headers)
#     446 def get_json(self, url, *, timeout, headers):
# --> 447     resp = self._request(url, timeout=timeout, headers=headers)
#     448     try:
#     449         return resp.json()
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\geopy\adapters.py:457, in RequestsAdapter._request(self, url, timeout, headers)
#     455 def _request(self, url, *, timeout, headers):
#     456     try:
# --> 457         resp = self.session.get(url, timeout=timeout, headers=headers)
#     458     except Exception as error:
#     459         message = str(error)
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\requests\sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\PycharmProjects\twitter_polls\venv\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
resolved
# Out:
# {'Joli Petit village de France': Location(La Jolie Vallée, Route de Moras Le Village, 38460, Route de Moras Le Village, Veyssilieu, Auvergne-Rhône-Alpes, France, (45.6806461, 5.2195177, 0.0)),
#  'maracay aragua': Location(Maracay, 2103, Aragua, Venezuela, (10.2375144, -67.5890216, 0.0)),
#  '2F CCJE, PSU Main': None,
#  'Ithaca NY ': Location(Ithaca High School, East Shore Drive, 14850, East Shore Drive, Ithaca, NY, United States, (42.45512515, -76.4992514459727, 0.0)),
#  'Picassent, Horta Sud, València': Location(Picassent, Comunitat Valenciana, España, (39.363519, -0.4611789, 0.0)),
#  'Πειραιάς': Location(Πειραιάς, 185 35, Αποκεντρωμένη Διοίκηση Αττικής, Ελλάς, (37.9431594, 23.6470593, 0.0)),
#  'Kairana, India': Location(Kairana, Uttar Pradesh, India, (29.4827179, 77.19151993121378, 0.0)),
#  ' Limassol, Cyprus': Location(Λεμεσός, 3085, Δήμος Λεμεσού, Κύπρος - Kıbrıs, (34.6852901, 33.0332657, 0.0)),
#  'muzon': Location(Muzon, 4112, Cavite, Philippines, (14.29169, 120.7520011, 0.0)),
#  'Gresham': Location(Gresham, Oregon, United States, (45.4997475, -122.4309766, 0.0)),
#  'sta.barbara,pangasinan': Location(Ruru Xin Sta. Barbara, Old National Road, 2419, Old National Road, Santa Barbara, Pangasinan, Philippines, (15.9980698, 120.4045638, 0.0)),
#  'Plymouth MI': Location(Plymouth, Minnesota, United States, (45.0065149, -93.46651, 0.0)),
#  'St Kitts And Nevis @Antigua': Location(St. Kitts Castle Condos, Kittian Village, Saint Kitts, Saint Kitts and Nevis, (17.28584855, -62.692829013508984, 0.0)),
#  'Toronto...ish': Location(Ishbel Lane, M4X 1P4, Toronto, Ontario, Canada, (43.6649357, -79.369003, 0.0)),
#  'İZMİR / Göztepe': Location(Göztepe, Konak, İzmir, Türkiye, (38.3973139, 27.0918506, 0.0)),
#  'sepang selangor': Location(Sepang, Selangor, Malaysia, (2.8008619, 101.7094012, 0.0)),
#  'BALAOANG PANIQUI,TARLAC': Location(Balaoang, 2307, Paniqui, Tarlac, Philippines, (15.6634172, 120.5129009, 0.0)),
#  'Washington253, USA ': None,
#  'Lagos and ilorin': Location(Ilorin Street, 101212, Itire, Lagos, Nigeria, (6.4989271, 3.348864, 0.0)),
#  'Georgia,TBILISI ': Location(თბილისი, საქართველო, (41.6934591, 44.8014495, 0.0)),
#  'Rhydaman/Ammanford': None,
#  'ItS mE ': Location(Itschnach, 8700, Küsnacht, Zürich, Schweiz/Suisse/Svizzera/Svizra, (47.3274435, 8.6008547, 0.0)),
#  'Saskatchewan!': Location(Saskatchewan, Canada, (55.5321257, -106.1412243, 0.0)),
#  'Newlands, Harare, Harare Provi': Location(Newlands Bypass, Harare, Harare, Zimbabwe, (-17.8108793, 31.072907, 0.0)),
#  'London & Zurich': Location(London & Zurich, Edward Street, B1 2RX, Edward Street, Birmingham, England, United Kingdom, (52.4809158, -1.9140884862314584, 0.0)),
#  'kumasi kronum Afrancho': Location(Kronum, Kumasi, Ashanti Region, Ghana, (6.7496217, -1.6432483, 0.0)),
#  'Satsang Vihar Nalanda ': Location(SATSANG VIHAR, India, (19.172794099999997, 73.2472113814238, 0.0)),
#  'Ridgewood, Queens': Location(Ridgewood, 11385, New York, New York, United States, (40.7080556, -73.9141667, 0.0)),
#  'Gitega, Q.Musinzira, Imm. INSS': None,
#  'Outside-the-Matrix': Location(Rossnaclonagh Outside, The Municipal District of Borris-in-Ossory — Mountmellick, Éire / Ireland, (52.980148, -7.606888577334429, 0.0)),
#  'Kelapa Gading, Jakarta Utara': Location(Kelapa Gading, 14250, Jakarta, Indonesia, (-6.15993785, 106.9024825763434, 0.0)),
#  'UST FMS 2021⚕': Location(Üstök-hegy, 2027, Magyarország, (47.7422398, 18.9190446, 0.0)),
#  'Canton, ohio': Location(Canton, Ohio, United States, (40.7985464, -81.3749508, 0.0)),
#  'Gauteng, johannesburg': Location(Johannesburg, 2001, Gauteng, South Africa, (-26.205, 28.049722, 0.0)),
#  'las vegas, USA': Location(Las Vegas, 06290, Usagre, Extremadura, España, (38.3585258, -6.177272, 0.0)),
#  'nosraC GoldenState': None,
#  'Plymouth': Location(Plymouth, England, United Kingdom, (50.3712659, -4.1425658, 0.0)),
#  'nabunturan comval': Location(Comval Hotel & Restaurant, Davao-Agusan National Highway, 8800, Davao-Agusan National Highway, Nabunturan, Davao de Oro, Philippines, (7.6069424, 125.966141, 0.0)),
#  'Phoenix, AZ usa': Location(AutoNation USA Phoenix, North 26th Avenue, 85023, North 26th Avenue, Phoenix, AZ, United States, (33.638834349999996, -112.11336885, 0.0)),
#  'Esreso,adagya': None,
#  'Liyue Harbor, Teyvat': None,
#  'bulacan cty': Location(CTC TV, Strada Ghioceilor, MD-2008, Strada Ghioceilor, Chișinău, Moldova, (47.0187499, 28.8003853, 0.0)),
#  'IRAN.TEHRAN': Location(تهران, استان تهران, ایران, (35.6892523, 51.3896004, 0.0)),
#  'Baraka RDC': Location(AlBaraka, Abdali Rd, 66000, Abdali Rd, ملتان, پنجاب, پاکستان, (30.19367, 71.453426, 0.0)),
#  'Southpark CO': Location(Southpark, Colonial Heights, Virginia, United States, (37.2530353, -77.39176585785836, 0.0)),
#  'ABUJA. ': Location(Abuja, 900001, Federal Capital Territory, Nigeria, (9.0643305, 7.4892974, 0.0)),
#  'Hindsville Arkansas': Location(Hindsville, 72738, Arkansas, United States, (36.1441448, -93.8626051, 0.0)),
#  'Intérêts : 🇧🇪 🇫🇷 🇺🇸 🇯🇵': Location(Parti Politique LDIC, Mususa, Nord-Kivu, République démocratique du Congo, (0.1248594, 29.2933344, 0.0)),
#  'somewhere on the earth': Location(The Good Earth Garden, Waterloo, Ontario, Canada, (43.46554955, -80.51483526032861, 0.0)),
#  'Sotkamo, Suomi': Location(Sotkamo, Manner-Suomi, Suomi, (64.1318262, 28.3878316, 0.0)),
#  'West Of The Mississippi': Location(CSA Army of the Mississippi - Forrest's Cavalry, Hamburg Purdy Road, 38376, Hamburg Purdy Road, Tennessee, United States, (35.1304603, -88.3361087, 0.0)),
#  'Tamandangápio': None,
#  'Centurion, Pothefstroom': None,
#  'Lubumbashi Rdcong': None,
#  'California Love!': Location(Lovelock, 95978, California, United States, (39.8912719, -121.5777512, 0.0)),
#  'Pinche Rubio |Arcoiris |Tabla ': None,
#  'Your mind🤷🏽\u200d♀️😛': Location(Mind Your Mouth, Montserrado, Liberia, (6.6491832, -10.5593005, 0.0)),
#  'In the Blockchain': Location(BlockchainSoft Inc., South Australian Avenue, 33401, South Australian Avenue, West Palm Beach, FL, United States, (26.709502, -80.0638395, 0.0)),
#  'NY / Bronx ': Location(Block Group 2, Bronx, NY, New York, New York, United States, (40.84236395, -73.89238192121559, 0.0)),
#  'Stuart FL USA': Location(Stuart, Florida, United States, (27.197983, -80.2519175, 0.0)),
#  'Davao Region, Republic of the': Location(Honorary Consulate of the Czech Republic, Monteverde Street, 8000, Monteverde Street, Davao City, Davao Region, Philippines, (7.0756332, 125.6194856, 0.0)),
#  'Inferno, Amazônia ': Location(Inferno, Uarini, Amazonas, Brasil, (-3.0318983, -65.1735233, 0.0)),
#  'نايم ... 😴 ال البد': Location(البردي, البطنان, ليبيا, (31.756018, 25.081821, 0.0)),
#  'MEDELLÍN, COLOMBIA 💋💕😁👍': Location(Medellín, 0500, Antioquia, Colombia, (6.2443382, -75.573553, 0.0)),
#  '31 Summerhill, Hobart,Tasmania': Location(Summerhill Road, 7000, Hobart, Tasmania, Australia, (-42.8775508, 147.3036392, 0.0)),
#  'black star': Location(Black Star, CA12 5XN, United Kingdom, (54.5161522, -3.2180567, 0.0)),
#  'California/Louisiana': Location(New California, Louisiana, United States, (30.8485169, -91.7451168, 0.0)),
#  'G-DRAGON FOREVER': Location(龙马明珠景区, 西湾跨海大桥, 538001, 西湾跨海大桥, 渔洲坪街道, 广西壮族自治区, 中国, (21.6352986, 108.3354232653061, 0.0)),
#  'Inis, Contae an Chláir.': Location(Radharc An Chlair, Galway, Éire / Ireland, (53.26345155, -9.071453437958521, 0.0)),
#  'ÜT: 30.24045,-97.822232': None,
#  'Partille': Location(Partille kommun, Sverige, (57.7333362, 12.1166649, 0.0)),
#  'San Juan, P.R.': Location(San Juan, Puerto Rico, United States, (18.465299, -66.116666, 0.0)),
#  'Some where in Harlem': Location(Whernside Crescent, TS17 0QF, Ingleby Barwick, England, United Kingdom, (54.5104359, -1.3126719, 0.0)),
#  'Eretz Yisroel someday': None,
#  'Ii': Location(Jan Paweł II, 中里橋, 850-8685, 中里橋, 長崎市, 長崎県, 日本, (32.7761763, 129.8679745, 0.0)),
#  'Pallipattu, India': Location(Pallipattu, 631207, Tamil Nadu, India, (13.3366218, 79.4408629, 0.0)),
#  ' Eliabethton, Tennessee, USA ': Location(Elizabethton, Tennessee, United States, (36.3487196, -82.2106876, 0.0)),
#  'Pflugerville , Tx ': Location(TX 45 Frontage Road, 78660, Pflugerville, Texas, United States, (30.4727232, -97.5922146, 0.0)),
#  'Ground #3PLAN@Area i.t. #thin3': Location(Grounds Field Area, India, (22.608786799999997, 88.31576395025306, 0.0)),
#  'Music City USA': Location(Twitty City-Music Village USA, 30766, United States, (36.324217, -86.5644394, 0.0)),
#  'AFRICA, EUROPA, AMERICA': Location(Boston African-American National Historic Site, 02108, United States, (42.3582464, -71.0678719, 0.0)),
#  'ÜT: -6.253227,106.848296': None,
#  'I Wanna Be Where U R:)': Location(Where It's at Road, Idaho, United States, (48.020827, -116.786962, 0.0)),
#  'À Butembo': Location(Institut les Anges, BP 355 Butembo, Vulamba, Nord-Kivu, République démocratique du Congo, (0.1444532, 29.2813147, 0.0)),
#  'Benin, Edo State': Location(Benin City, 300241, Edo, Nigeria, (6.3330586, 5.6221058, 0.0)),
#  'Menlo Park,  South Africa': Location(Menlo Park, 0047, Pretoria, Gauteng, South Africa, (-25.7697222, 28.2555556, 0.0)),
#  'SP-MAIRINQUE': Location(Sandra Spa, Calle 71A, 050011, Calle 71A, Comuna 3 - Manrique, Antioquia, Colombia, (6.2661743, -75.54377, 0.0)),
#  'in case im suspended': Location(Caseiros, 95315-000, Rio Grande do Sul, Brasil, (-28.2721149, -51.6873536, 0.0)),
#  'Pedralva, Brasil': Location(Pedralva, Minas Gerais, Brasil, (-22.2428119, -45.4659922, 0.0)),
#  'Ceann Phadraig, Scotland': Location(Ceannabeinne, IV27 4QD, Alba / Scotland, United Kingdom, (58.5526327, -4.6856165, 0.0)),
#  'South Africa,Pongola': Location(Pongola River, 3180, South Africa, (-27.4071501, 31.4813956, 0.0)),
#  'Azerbaijan,Ismayilli🇦🇿': Location(İsmayıllı, Dağlıq Şirvan, Azərbaycan, (40.788056, 48.1485653, 0.0)),
#  'ADDIS': Location(አዲስ አበባ / Addis Ababa, 1138, ኣዲስ ኣበባ / Addis Ababa, ኢትዮጵያ, (9.0107934, 38.7612525, 0.0)),
#  'Great Lakes State ': Location(Great Lakes, 60088, North Chicago, Illinois, United States, (42.3093241, -87.8496551, 0.0)),
#  "USMC - Veteran - Semper Fi'": None,
#  'Location Yet To Be Found.': None,
#  'Bosque de Agua (Morelos)': Location(Jardines de Morelos Sección Bosques, 55070, Ecatepec, Estado de México, México, (19.5918856, -98.9999658, 0.0)),
#  'Socorro, Surigao del Norte ': Location(Socorro, 8416, Surigao del Norte, Philippines, (9.6183104, 125.9650671, 0.0)),
#  'Leb/Can': Location(Canada da Lebre, 6370-401, Portugal, (40.5675453, -7.5352471, 0.0)),
#  'Ramat-Gan, Israel': Location(רמת גן, מחוז תל אביב, ישראל, (32.0686867, 34.8246812, 0.0)),
#  '134 rue de la Pompe Paris 16': Location(134, Rue de la Pompe, 75116, Rue de la Pompe, Paris, Île-de-France, France, (48.8684281, 2.2815755, 0.0)),
#  "Orwell's 1984": Location(Orwell, New York, United States, (43.5747959, -75.996258, 0.0)),
#  'Bintaro jaya': Location(Lingk. Bintaro Jaya, 83111, Mataram, Nusa Tenggara Barat, Indonesia, (-8.5562118, 116.0720051, 0.0)),
#  "In your dreams Beshie's": Location(In Your Dreams, Upplandsgatan, 114 30, Upplandsgatan, Stockholm, Sverige, (59.338992, 18.0519689, 0.0)),
#  'Scotland (UK)': Location(Total E&P UK, Aberdeen, Alba / Scotland, United Kingdom, (57.11223335, -2.0872488374421962, 0.0)),
#  'Botleng': Location(Botleng, 2210, South Africa, (-26.099518, 28.6880797, 0.0)),
#  'Thornhill, ON, Canada ': Location(Thornhill, L4J 4E5, Vaughan, Ontario, Canada, (43.8161477, -79.4245925, 0.0)),
#  'In front of stage ': Location(Bog in front of Fokir bari, Bangladesh, (22.585982100000003, 90.6296871416075, 0.0)),
#  'EU?': Location(, (51.0, 10.0, 0.0)),
#  'Aguadilla Vacation Condo Las D': None,
#  'Hapur (India)': Location(Hapur, Uttar Pradesh, India, (28.740612499999997, 77.83542556519009, 0.0)),
#  'Pelo Mundo': Location(Rua Pelotas, 79950-000, Naviraí, Mato Grosso do Sul, Brasil, (-23.0681026, -54.1971396, 0.0)),
#  'badas - kediri - JATIM': Location(Badal, Jawa Timur, Indonesia, (-7.8775373, 111.9801093, 0.0)),
#  'Wartrace,TN': None,
#  'Marvel Studios. Disney ': Location(Walt Disney Studios, Ventura Freeway, 91522, Ventura Freeway, Burbank, California, United States, (34.1566667, -118.32494472464316, 0.0)),
#  'Somewhere Over There': Location(Somewhere Over There, V8B 0N8, Area D (Elaho/Garibaldi), British Columbia, Canada, (49.7273576, -123.0837289, 0.0)),
#  'Palawan Phillippines': Location(Palawan, Philippines, (11.083365350000001, 120.91639641658887, 0.0)),
#  'on the run, shhhh': Location(On The Run #14, Louisiana, United States, (30.355265799999998, -90.99212732021964, 0.0)),
#  'Doncaster united kingdom🇬🇧': Location(Doncaster, England, United Kingdom, (53.5227681, -1.1335312, 0.0)),
#  'ÜT: 41.797623,-71.401931': None,
#  'Villa de calamba laguna': Location(Villa De Calamba, 4027, Calamba, Laguna, Philippines, (14.19059, 121.15894230021914, 0.0)),
#  'all over enjoying gods love': None,
#  'São paulo,Brazil': Location(São Paulo, São Paulo, Brasil, (-23.5506507, -46.6333824, 0.0)),
#  'Все равно не поверите)': None,
#  'Earth, London': Location(Fired Earth, Court Road, BR6 7RF, Court Road, London, England, United Kingdom, (51.3500561, 0.13139779507435467, 0.0)),
#  'laguna sanpedro': Location(La Laguna, 24545, Sancedo, Castilla y León, España, (42.6770769, -6.6471819, 0.0)),
#  'Manvel, TX.': Location(Manvel Police Department, 77578, Manvel, TX, United States, (29.468782, -95.359765, 0.0)),
#  'Chicago, WestSide': Location(Westside Preparatory School, West Chicago Avenue, 60651, West Chicago Avenue, Chicago, IL, United States, (41.8955877, -87.730612, 0.0)),
#  'Where VA meets NC': Location(Meester van Busselstraat, 5731 NC, Mierlo, Noord-Brabant, Nederland, (51.4395483, 5.626549, 0.0)),
#  'where am meant to be.': Location(Yazaki North America - Circuit Control Corporation, Little Traverse Wheelway, 49722, Little Traverse Wheelway, Bear Creek Township, Michigan, United States, (45.40289565, -84.90278353731861, 0.0)),
#  'Heraklion,Crete,Greece': Location(Ηράκλειο, 712 02, Δημοτική Ενότητα Ηρακλείου, Αποκεντρωμένη Διοίκηση Κρήτης, Ελλάς, (35.33908, 25.1332843, 0.0)),
#  'ABUJA, Nigerian': Location(Nigerian Air Force Base Abuja, Nigeria, (8.97322155, 7.262740320151061, 0.0)),
#  'Jayapura/papua': Location(Jayapura, Papua, Indonesia, (-2.5387539, 140.7037389, 0.0)),
#  'Macapá-ap Brasil': Location(Nossa Senhora Aparecida, Macapá, Amapá, Brasil, (0.8892159, -50.0838456, 0.0)),
#  'Birmingham/Sheffield UK': Location(Sheffield Sheds, Birmingham, England, United Kingdom, (52.53810585, -1.8326574922898065, 0.0)),
#  'Nigeria;South Africa; Botswana': Location(African Mall, Gaborone, South-East District, Botswana, (-24.66388835, 25.916543083404825, 0.0)),
#  'somewhere in slemani': Location(Slemanan, Jawa Timur, Indonesia, (-8.0014733, 112.0481593, 0.0)),
#  'Baabda lebanon': Location(بعبدات, 1235, محافظة جبل لبنان, لبنان, (33.8872681, 35.6675434, 0.0)),
#  'Earth, third planet from sun': None,
#  'Ouanaminthe, Haiti': Location(Ouanaminthe, 2210, Commune Ouanaminthe, Nord-Est, Ayiti, (19.5485315, -71.7258332, 0.0)),
#  'Patel Nagar Delhi': Location(Patel Nagar (East), Patel Road, 110008, Patel Road, Delhi, India, (28.6450527, 77.1693179, 0.0)),
#  'السويداء': Location(السويداء, محافظة السويداء, سوريا, (32.7093878, 36.5687496, 0.0)),
#  ' Calamba, Laguna': Location(Calamba, Laguna, Philippines, (14.2060217, 121.1556496, 0.0)),
#  'En Tu Siempre Sucio, Princesa.': None,
#  'Baltimora, Maryland ': Location(Baltimore, Maryland, United States, (39.2908816, -76.610759, 0.0)),
#  'TUNDURU': Location(Tunduru, Ruvuma, Tanzania, (-10.8988426, 37.38874059876646, 0.0)),
#  'PSN: Crioh-': None,
#  'Providence city, KY, USA': Location(Providence Dental Clinic, Kyogwe, Kyogwe, Kampala, Central Region, Uganda, (0.3185438, 32.5750932, 0.0)),
#  'Ouagadougou-BurkinaFaso': None,
#  'Wagmi': Location(Wagmin Kartopawiroweg, Smal Kalden, Para, Suriname, (5.6239483, -55.0915986, 0.0)),
#  'ubs arena': Location(Motoball-Arena Ubstadt-Weiher, 76698, Ubstadt-Weiher, Baden-Württemberg, Deutschland, (49.1710106, 8.620228881017997, 0.0)),
#  'WASHINGTON, D.C.': Location(Washington, District of Columbia, United States, (38.8950368, -77.0365427, 0.0)),
#  'City of Salford UK ': Location(University of Salford, Orange, M50 2HF, Orange, Salford, England, United Kingdom, (53.47322035, -2.2970993110055513, 0.0)),
#  'Santa Ana, El Salvador-301188': Location(Departamento de Santa Ana, El Salvador, (14.114974499999999, -89.56791987293877, 0.0)),
#  'Kansas, Lawrence': Location(Lawrence, Kansas, United States, (38.9719384, -95.2359496, 0.0)),
#  'Ostróda, Polska ': Location(Ostróda, województwo warmińsko-mazurskie, Polska, (53.7028533, 19.9623028, 0.0)),
#  'EDEN': Location(Eden Park, Cricket Avenue, 1021, Cricket Avenue, Albert-Eden, Auckland, New Zealand / Aotearoa, (-36.8750352, 174.7440567126547, 0.0)),
#  '#LaLibertad': Location(Andador de Lalibertad, 58110, Morelia, Michoacán, México, (19.7359785, -101.1994006, 0.0)),
#  'London/Bath': Location(Roman Bath, Strand Lane, WC2R 2NA, Strand Lane, London, England, United Kingdom, (51.511658, -0.115674, 0.0)),
#  'Pecola Fl': Location(Florais Pérola, Brasil, (-15.55006405, -56.113078116973384, 0.0)),
#  'where ever i feel like being ': None,
#  'In your mind☑': Location(Total Environment - Windmills Of Your Mind, Whitefield Road, 560066, Whitefield Road, Bangalore, Karnataka, India, (12.9840786, 77.72144019896032, 0.0)),
#  'Santa isabel_SP': Location(Avenida Sangangüey, 63784, Xalisco, Nayarit, México, (21.451167, -104.9020388, 0.0)),
#  'NYC • LA': Location(Nyckelby, 746 93, Håbo kommun, Sverige, (59.6047032, 17.4476834, 0.0)),
#  'Portage, PA': Location(Portage Park, 60630, Jefferson Township, Illinois, United States, (41.9578093, -87.7650594, 0.0)),
#  '🤷🏾\u200d♂️🤷🏾\u200d♂️🤷🏾\u200d♂️': None,
#  'In X Isle': Location(Kasa Isles xx, Noida-Greater Noida Expressway, 201304, Noida-Greater Noida Expressway, Noida, Uttar Pradesh, India, (28.50540565, 77.38842266534166, 0.0)),
#  'Maracay, edo. Aragua': Location(Palacio de Gobierno del Estado Aragua, Av. General Paez, 1201, Av. General Paez, Maracay, Aragua, Venezuela, (10.2540666, -67.59244268169057, 0.0)),
#  'Zambia kitwe (chachacha)': Location(Kitwe, 1001, Copperbelt Province, Zambia, (-12.8104186, 28.2068361, 0.0)),
#  'Manticao, Rehiyon ng Hilagang ': None,
#  'Between Detroit and Atlanta': Location(Between Fairlie and Forsth, Poplar Street Northwest, 30303, Poplar Street Northwest, Atlanta, GA, United States, (33.7568241, -84.390137, 0.0)),
#  'Belitung Timur': Location(Belitung Timur, Bangka Belitung, Indonesia, (-2.9164574, 108.00372175752332, 0.0)),
#  'อ่อนนุช บางจาก ': None,
#  '9-ый круг Ада': Location(Кружаль, 1/9, улица 3 Июля, 664022, улица 3 Июля, Иркутск, Иркутская область, Россия, (52.2757043, 104.2867896, 0.0)),
#  'In the past': Location(Park in the Past, United Kingdom, (53.1247855, -3.0466274116035166, 0.0)),
#  'Bucharest, Roumanie': Location(București, România, (44.4361414, 26.1027202, 0.0)),
#  'St. Simons Island and Boston': Location(Boston and Providence Railroad Bridge, Roger Williams Avenue, 02916, Roger Williams Avenue, Rumford, Rhode Island, United States, (41.8349164, -71.36202130742276, 0.0)),
#  'Forecastilation Station, OH': Location(Davis-Besse Nuclear Power Station, Carroll Township, OH, United States, (41.593329749999995, -83.08084569825326, 0.0)),
#  'cidade dos anjos ': Location(Rua dos Anjos, 29163-553, Serra, Espírito Santo, Brasil, (-20.216916, -40.2310753, 0.0)),
#  '🙊🙈🙉': None,
#  'Chino-shi, Nagano': Location(長野県信用組合, 甲州街道, 391-8511, 甲州街道, 茅野市, 長野県, 日本, (35.98795225, 138.15067293342435, 0.0)),
#  'Kab.Mempawah  Gang Kencana': Location(Gang Kencana, 28772, Kelurahan Padang Bulan, Riau, Indonesia, (0.5313491, 101.4385105, 0.0)),
#  'The Deep South, SC ': Location(The Deepings School, Spalding Road, PE6 8NF, Spalding Road, South Kesteven, England, United Kingdom, (52.675463449999995, -0.29697649634471546, 0.0)),
#  'rwmealplanning@gmail.com': Location(dsantri.official@gmail.com, Kp. Sukajadi RT.006 RW.012, 40375, Kp. Sukajadi RT.006 RW.012, Bandung, Jawa Barat, Indonesia, (-6.9986809999999995, 107.67234847779713, 0.0)),
#  'kozani, greece': Location(Κοζάνη, 50100, Αποκεντρωμένη Διοίκηση Ηπείρου - Δυτικής Μακεδονίας, Ελλάς, (40.3007259, 21.7883119, 0.0)),
#  'any pronouns 🌟 20+': Location(Polish Institute and Sikorski Museum, 20, Princes Gate, SW7 1PZ, Princes Gate, London, England, United Kingdom, (51.5014271, -0.1728715687498128, 0.0)),
#  'Milkey way ': Location(Milkey Way, Path Valley Rd, 17224, Path Valley Rd, Peters Township, PA, United States, (39.916464149999996, -77.91101420026328, 0.0)),
#  'd. f.': Location(AT&T, 1661F, Fort Campbell Boulevard, 37042, Fort Campbell Boulevard, Clarksville, TN, United States, (36.5793042, -87.4088336, 0.0)),
#  '$traight outta kyu$i': Location(Водоприймач, Леніна проспект, 01196, Леніна проспект, Київська область, Україна, (51.381633550000004, 30.1154571, 0.0)),
#  '93 Ibeto Road, Port Harcourt': Location(Ibeto Cement, Ship Builders Road, 520052, Ship Builders Road, Port Harcourt, Rivers, Nigeria, (4.7516596, 7.004299944333447, 0.0)),
#  'Somewhere in New Jersey': Location(Somewhere In Time, Raritan Avenue, 08904, Raritan Avenue, Highland Park, NJ, United States, (40.4989496, -74.4288771, 0.0)),
#  'Kansas City / LA': Location(Lake City, 67071, Kansas, United States, (37.3533557, -98.8209282, 0.0)),
#  ' Raccoon City': Location(Raccoon Valley, 37807, Maynardville City Limits, Tennessee, United States, (36.2295249, -83.8418551, 0.0)),
#  'Canlan City Negros Oriental': Location(Canlaon, 6223, Negros Oriental, Philippines, (10.386953, 123.2186238, 0.0)),
#  'Southwestern Pennsylvania, USA': Location(Pennsylvania Crescent, N2P 1H7, Kitchener, Ontario, Canada, (43.4021648, -80.4191162, 0.0)),
#  'Atteridgevill Pretoria': Location(Atteridgeville, Moroe Street, 0006, Moroe Street, Pretoria, Gauteng, South Africa, (-25.7634489, 28.0737228, 0.0)),
#  'At The Debtors Den': Location(The Center at Deane Hill, Knoxville, Tennessee, United States, (35.92545245, -84.0319709554674, 0.0)),
#  'Western Massachusetts ': Location(Western Massachusetts Electric, United States, (42.04938, -72.64106676598658, 0.0)),
#  'Endicott, NY': Location(West Endicott Park Carousel, Maple Street, 13760, Maple Street, Endicott, NY, United States, (42.0981344, -76.074284775, 0.0)),
#  'Aldeia da Folha': Location(Aldeias, 6290-012, Aldeias e Mangualde da Serra, Portugal, (40.4687182, -7.5982209, 0.0)),
#  'R.DCongo': Location(dcondo rin, เชียงใหม่, จังหวัดเชียงใหม่, ประเทศไทย, (18.8080225, 99.0167972273099, 0.0)),
#  'En Mi Venezuela Por Ahora..! ': Location(C-MIX-2018-11-0048, Guatire, Miranda, Venezuela, (10.46631065, -66.55375339005535, 0.0)),
#  'Valdosta, Ga': Location(Valdosta Regional Airport, Old Clyattville Road, 31601, Old Clyattville Road, GA, United States, (30.77831025, -83.2780341085929, 0.0)),
#  'Accra. .. OSU ghost town': Location(Osun Lane, GA-254-4987, Greater Accra Region, Ghana, (5.6097309, -0.2448951, 0.0)),
#  '3.6.O.L.Y.': Location(ИС-3, Первомайская улица, 650075, Первомайская улица, Екатеринбург, Свердловская область, Россия, (56.8439043, 60.6204462, 0.0)),
#  'castle black ': Location(MTU Blackrock Castle Observatory, Castle Road, T12 KP11, Castle Road, Cork, Éire / Ireland, (51.900327, -8.40238553530337, 0.0)),
#  'Sanditon/221B/Storybrooke ': None,
#  'kinshasa Rd congo': Location(République démocratique du Congo, République démocratique du Congo, (-2.9814344, 23.8222636, 0.0)),
#  'with my brothers': Location(Brothertoft, PE20 3SN, Boston, England, United Kingdom, (52.9952826, -0.1042067, 0.0)),
#  'A galaxy far far away....': Location(فەرەجاوا, پارێزگای سلێمانی, العراق, (35.4684419, 45.482669, 0.0)),
#  'York Springs Pa': Location(Gerard Park, East Hampton, New York, United States, (41.0434333, -72.1461884, 0.0)),
#  'T.sora, Q.c': Location(Tandang Sora, 1116, Quezon City, Metro Manila, Philippines, (14.6796761, 121.0380661, 0.0)),
#  'graha prima baru blok m': Location(Mangolkote Block Primary Health Centre, 713174, West Bengal, India, (23.529629, 87.906549, 0.0)),
#  'witzhelden': Location(Witzhelden, 51399, Leichlingen, Nordrhein-Westfalen, Deutschland, (51.1155786, 7.1104346, 0.0)),
#  'Some Where Applying Pressure': None,
#  'Go subscribe to me': Location(Conches-sur-Gondoire, 77600, Île-de-France, France, (48.8543635, 2.7219163, 0.0)),
#  'London, England and Ibiza': Location(London Borough of Hammersmith and Fulham, London, England, United Kingdom, (51.498314199999996, -0.22787818358222445, 0.0)),
#  'Life Path 7⃣': Location(Pataz, La Libertad, Perú, (-8.2024294, -77.3141069, 0.0)),
#  'https://youtu.be/_mWtWz_aGyk': None,
#  'Dover, Kent, UK': Location(HSBC UK, Pencester Road, CT16 1BJ, Pencester Road, Dover, England, United Kingdom, (51.1268539, 1.3114186, 0.0)),
#  'Tulunan North Cotabato': Location(Tulunan, North Cotabato, Philippines, (6.8300214, 124.8736479, 0.0)),
#  'Blue Oasis in Southern State': Location(Oasis Street, 92201, Indio, California, United States, (33.7160124, -116.2207487, 0.0)),
#  'New York - Caracas': Location(New York USA Pizza, Avenida Principal de Propatria, 1030, Avenida Principal de Propatria, Caracas, Distrito Capital, Venezuela, (10.5037031, -66.9532545, 0.0)),
#  'Sallisaw, Oklahoma': Location(Sallisaw, 74955, Oklahoma, United States, (35.4587305, -94.7879436, 0.0)),
#  'mpumala': Location(Mpumalanga, South Africa, (-26.276849, 30.1500153, 0.0)),
#  '2030 33 Ave SW Calgary, AB': Location(Lava Hair, 2030, 33 Avenue SW, T2T 1Y4, 33 Avenue SW, Calgary, Alberta, Canada, (51.0243173, -114.1086148, 0.0)),
#  'Bắc Việt Luật': Location(Trường Trung cấp Luật Tây Bắc, Đường Trần Phú, Đường Trần Phú, Sơn La, Tỉnh Sơn La, Việt Nam, (21.27993885, 103.98539422377635, 0.0)),
#  'proche orient': Location(Belle d'Orient, Proche Rue Victor Hugo, 601, Proche Rue Victor Hugo, Toliara, Atsimo-Andrefana, Madagasikara, (-23.3526997, 43.6691471, 0.0)),
#  'east selkirk': Location(East Selkirk, R0E 0M0, Rural Municipality of St. Clements, Manitoba, Canada, (50.1394189, -96.8389431, 0.0)),
#  'Chiba City Inage Ward, Chiba': Location(プラウドシティ・イースト, 東京湾岸道路, 260-0032, 東京湾岸道路, 千葉市, 千葉県, 日本, (35.638437, 140.07543, 0.0)),
#  'basingstoke, hampshire': Location(Basingstoke, Basingstoke and Deane, England, United Kingdom, (51.262826, -1.0861976, 0.0)),
#  'Baltimore, Maryland.': Location(Baltimore, Maryland, United States, (39.2908816, -76.610759, 0.0)),
#  '서울시 강동구 천호2동 563 이천일아울렛 천호점': Location(서울강동초등학교, 천중로17길, 05330, 천중로17길, 서울, 대한민국, (37.545910750000004, 127.12996905810411, 0.0)),
#  'London / Milton Keynes': Location(London Road Allotments, Stony Stratford, England, United Kingdom, (52.0543737, -0.8457083910027947, 0.0)),
#  'Deep in the swamp, digging 4 t': Location(Deepak Company, Ghodbunder Baug Road, Ghodbunder Village, 401107, Ghodbunder Baug Road, Ghodbunder Village, Thane, Maharashtra, India, (19.2909689, 72.8938826326766, 0.0)),
#  'San Roque, Calabanga, Camarine': Location(San Roque Elementary School, Calabanga Road, 4403, Calabanga Road, Magarao, Camarines Sur, Philippines, (13.676103, 123.20413274426099, 0.0)),
#  'Tema, Ghana  ': Location(Tema, GT-020-5892, Greater Accra Region, Ghana, (5.6596441, -0.0096592, 0.0)),
#  '🐰🐥を近くで見守る位置': None,
#  'NEXT DOOR🏠': Location(Next Door Trail, 27030, North Carolina, United States, (36.437732, -80.619168, 0.0)),
#  'Unknown. ': Location(Unknown, မြန်မာ, (24.9591486, 95.8030352, 0.0)),
#  ' Nuevo Progreso,Tam.,Mx': Location(Nuevo Progreso, Tamaulipas, México, (26.0544108, -97.9518067, 0.0)),
#  'clarin misamis occidental': Location(Clarin, 7201, Misamis Occidental, Philippines, (8.1998924, 123.8616135, 0.0)),
#  'Sarteano, Toscana': Location(Sarteano, 53047, Toscana, Italia, (42.989911, 11.8687316, 0.0)),
#  'quezon city metro manila': Location(Quezon City, 1100, Metro Manila, Philippines, (14.6509905, 121.0486155, 0.0)),
#  ' BOOMERSOONER/THUNDERNATION': None,
#  'Ohio usa': Location(Southgate USA, Maple Heights, Ohio, United States, (41.414935, -81.5323381136422, 0.0)),
#  'mokopane SA': Location(Sasol, Mogalakwena Local Municipality, Limpopo, South Africa, (-24.272712, 28.9955644, 0.0)),
#  'phillippines\\': Location(Bangko Sentral ng Pilpinas, C. M. Recto Avenue, 9000, C. M. Recto Avenue, Cagayan de Oro, Northern Mindanao, Philippines, (8.4858944, 124.64879778954048, 0.0)),
#  'New Wilmington, PA': Location(Canby Park Estates, 19805, Wilmington, Delaware, United States, (39.7390019, -75.5815912, 0.0)),
#  'San Vicente, Palawan, Phil.': Location(San Vicente, 5309, Palawan, Philippines, (10.5277363, 119.2569404, 0.0)),
#  'دمياط/مصر': Location(دمياط, 34511, دمياط, مصر, (31.4167427, 31.8213657, 0.0)),
#  'dar es salaam, tanzania': Location(Dar es-Salaam, Coastal Zone, Tanzania, (-6.8160837, 39.2803583, 0.0)),
#  'District of Champions': Location(Champions of the world, Rees Street, 9200, Rees Street, Queenstown, Otago, New Zealand / Aotearoa, (-45.0322492, 168.6595635, 0.0)),
#  'Lagos | Portharcourt , Nigeria': Location(Portharcourtgbene, Bayelsa, Nigeria, (4.455437, 5.950268, 0.0)),
#  'Maya St.Unit 5 Brgy. Comm. QC': Location(Commercial Street, 52586, Rose Hill, Iowa, United States, (41.3190291, -92.4602949, 0.0)),
#  "I'm from Ukraine ": Location(Міжрегіональна Академія управління персоналом, Фрометівська вулиця, 03118, Фрометівська вулиця, Київ, Україна, (50.4099005, 30.512380481615633, 0.0)),
#  'Still Trying To Leave America.': None,
#  'Cuya': Location(Cuyahoga, Ohio, United States, (41.4301347, -81.6905558, 0.0)),
#  'aqui y ahora': Location(Aqui y Ahora, Avenida Marítima, 38530, Avenida Marítima, Candelaria, Canarias, España, (28.3672839, -16.3635184, 0.0)),
#  'Lincoln, Nebraska U.S.A.': Location(Lincoln, Nebraska, United States, (40.8088861, -96.7077751, 0.0)),
#  'You found me.': Location(Hope For The Youth Foundation, Taft Avenue, 1000, Taft Avenue, Manila, Metro Manila, Philippines, (14.5781556, 120.9874105, 0.0)),
#  'New York City,NY': Location(New York City Center, 6½ Avenue, 10106, 6½ Avenue, New York, NY, United States, (40.7639353, -73.97946023256337, 0.0)),
#  'Sydenham Road Croydon  CR0 2EH': Location(Sydenham Road, CR0 2ED, London, England, United Kingdom, (51.3868671, -0.0918069, 0.0)),
#  'World Chain ⛓️': Location(Plac manewrowy WORD Łuków, Łuków, województwo lubelskie, Polska, (51.931058699999994, 22.377933961423693, 0.0)),
#  'ecatepec edo mex': Location(Ecatepec, Estado de México, México, (19.5994083, -99.0487281, 0.0)),
#  'Lembang, Bandung': Location(Lembang, 40391, Jawa Barat, Indonesia, (-6.8111033, 107.6171239, 0.0)),
#  'na merda ': Location(Quai du Merdancon, 01100, Arbent, Auvergne-Rhône-Alpes, France, (46.2958222, 5.6812399, 0.0)),
#  'Leaving Idaho': Location(Leaping Alice Road, Idaho, United States, (45.8720604, -115.6360656, 0.0)),
#  'iloilo City': Location(Iloilo City, 5000, Western Visayas, Philippines, (10.7026718, 122.5686136, 0.0)),
#  'NUN .  of   Ya .  buz.drive🧐': Location(Gunyulgup Valley Drive, 6282, Yallingup, Western Australia, Australia, (-33.6648157, 115.0399216, 0.0)),
#  'Monterrey N.L. México': Location(Monterrey, 64010, Nuevo León, México, (25.6802019, -100.315258, 0.0)),
#  ' Redford': Location(Redford Township, 48239, Michigan, United States, (42.3945469, -83.2953927, 0.0)),
#  'Red China': Location(Red River, 661300, 中国, (22.854975, 103.5647573, 0.0)),
#  'Willowbrook, IL': Location(Willowbrook, Illinois, United States, (41.4527885, -87.54108782390354, 0.0)),
#  'Lubumbashi drc🇨🇩🇨🇩': None,
#  'capital federal, argentina': Location(Ciudad Autónoma de Buenos Aires, Argentina, (-34.61612315, -58.43562340522388, 0.0)),
#  'Dramatic Film Coming in 2020': None,
#  'firozabad': Location(Firozabad, 283203, Uttar Pradesh, India, (27.1527986, 78.3991439, 0.0)),
#  'Hopkins, MN': Location(Hopkins Arches Apts, 2nd St NE, 55343, 2nd St NE, Hopkins, MN, United States, (44.9289167, -93.3878711, 0.0)),
#  'ÜT: 17.5821826,120.3879602': None,
#  'Nisqually Land ': Location(Nisqually John Landing Recreation Area, United States, (46.4764933, -117.23553788546974, 0.0)),
#  'Sicilia, Italia': Location(Sicilia, Italia, (37.587794, 14.155048, 0.0)),
#  'Not near a Cottage Coward POS': Location(Cottage Point, 2084, Northern Beaches Council, New South Wales, Australia, (-33.6195161, 151.203318, 0.0)),
#  'to the Moon': Location(Trip to the Moon, West Virginia, United States, (39.2498929, -81.292691, 0.0)),
#  'Oakland-San Fran-Bay Area, CA': Location(San Francisco – Oakland Bay Bridge, 94017, San Francisco, California, United States, (37.7885108, -122.3882669, 0.0)),
#  'Santiago de surco Perú ': Location(Santiago de Surco, Lima, Perú, (-12.1251049, -76.98216049214285, 0.0)),
#  'aviles': Location(Avilés, Principado de Asturias, España, (43.5554436, -5.9222466, 0.0)),
#  'Venezuela(cumana y pto ordaz)': None,
#  'the michigan khanate': Location(TPC Michigan, Turnburry Lane, 48120, Turnburry Lane, Dearborn, Michigan, United States, (42.3067772, -83.20146975879058, 0.0)),
#  'Not Telling You Avenue': Location(5th Avenue, 10035, New York, New York, United States, (40.745301, -73.986846, 0.0)),
#  'i\U0001faf6🏻TINNapay': Location(Tinnapatti, 636305, Tamil Nadu, India, (11.8096029, 78.0972372, 0.0)),
#  'New Zealand, Sydney, Hong Kong': Location(New Hong Kong Takeaway, Tonkin Drive, 0732, Tonkin Drive, Devonport-Takapuna, Auckland, New Zealand / Aotearoa, (-36.7545911, 174.7403887, 0.0)),
#  'Quezon City. philippines': Location(Quezon City, 1100, Metro Manila, Philippines, (14.6509905, 121.0486155, 0.0)),
#  'Rutland, North Dakota': Location(Rutland, 58067, North Dakota, United States, (46.053019, -97.508984, 0.0)),
#  'The city that never sleep': Location(The Tree that Never Grew by Jennifer Grant, Duke Street, G4 0UP, Duke Street, Glasgow, Alba / Scotland, United Kingdom, (55.8592806, -4.232919, 0.0)),
#  'baybay leyte': Location(Baybay, 6521, Leyte, Philippines, (10.6777771, 124.7977452, 0.0)),
#  'なむじゅん': None,
#  'somewhere on 🌎 ': Location(Trail to Somewhere, L0N 1M0, Mulmur, Ontario, Canada, (44.2111637, -80.014796, 0.0)),
#  '4403': Location(طريق 4403, 109, الحد, محافظة المحرق, البحرين, (26.2554387, 50.6465792, 0.0)),
#  'Ojo Alaba, Lagos Nigeria': Location(Alaba International Market, Ojo, Lagos, Nigeria, (6.4604859999999995, 3.190618113580034, 0.0)),
#  'Global Baddies': None,
#  'HOY': Location(Hoy, United Kingdom, (58.8520573, -3.2869398422535223, 0.0)),
#  'Brockville, Ontario': Location(Brockville, K6V 3P9, Ontario, Canada, (44.5895925, -75.6843332, 0.0)),
#  'Seoul, Republic of Korea charr': Location(Embassy of Democratic People's Republic of Korea, Prince Charles Drive, Prince Charles Drive, Kampala, Central Region, Uganda, (0.3321871, 32.5971682, 0.0)),
#  'Northern Bruce Peninsula': Location(Bruce Peninsula National Park, Municipality of Northern Bruce Peninsula, Ontario, Canada, (45.19416365, -81.53201455516114, 0.0)),
#  'Uk, London ': Location(Royal Courts of Justice, Strand, WC2A 2LL, Strand, London, England, United Kingdom, (51.51419575, -0.11347677488453559, 0.0)),
#  'En el planeta tierra': Location(El Encinar, Santibáñez el Bajo, Extremadura, España, (40.1952185, -6.2478205, 0.0)),
#  'South Weald ': Location(South Weald, CM14 5QJ, Brentwood, England, United Kingdom, (51.6207568, 0.2690058, 0.0)),
#  'dryden va': Location(Varna, Dryden, New York, United States, (42.4550726, -76.4379939, 0.0)),
#  'I’ll be at the Sportsbook ': None,
#  "Xavier's school For Gifted": Location(Trường Chuyên Lê Quý Đôn, Ba Tháng Hai, 78000, Ba Tháng Hai, Vũng Tàu, Bà Rịa-Vũng Tàu, Việt Nam, (10.38999445, 107.13489105431896, 0.0)),
#  'By the sea 🌊': Location(Carmel-by-the-Sea, California, United States, (36.5552656, -121.923278, 0.0)),
#  'Anambra state nigeria': Location(Anambra, Nigeria, (6.2183136, 6.9531842, 0.0)),
#  '東京都粒谷区': Location(京あづま, 都市計画道路補助第154号線（区役所西通り）, 154-0022, 都市計画道路補助第154号線（区役所西通り）, 東京都, 日本, (35.6619734, 139.6544183, 0.0)),
#  'Lethbridge ': Location(Lethbridge, Alberta, Canada, (49.6945782, -112.8331033, 0.0)),
#  'Carlisle': Location(Carlisle, England, United Kingdom, (54.8948478, -2.9362311, 0.0)),
#  'Right where you wanna be.... ': None,
#  'Uk\n': Location(Україна, Україна, (49.4871968, 31.2718321, 0.0)),
#  'Junin, Buenos Aires': Location(Junín, Buenos Aires, Argentina, (-34.5934412, -60.9461678, 0.0)),
#  'Somewhere i love ': Location(Somewhere In Time Lane, 12768, Liberty, New York, United States, (41.86628, -74.7650315, 0.0)),
#  'Bauchi.': Location(Bauchi, Nigeria, (10.6228284, 10.0287754, 0.0)),
#  'Johor bahru, malaysia': Location(Johor Bahru, 80350, Johor, Malaysia, (1.503555, 103.7495586, 0.0)),
#  'Khartoum Sudan': Location(الخرطوم, الخرطوم, السودان, (15.5635972, 32.5349123, 0.0)),
#  'Balneário Camboriú': Location(Balneário Camboriú, Santa Catarina, Brasil, (-26.9924395, -48.6339782, 0.0)),
#  "Murang'a Mathioya Kiru Kairo ": None,
#  '△\u2003i n  w o n d e r l a n d': Location(L A W I R, 86513, Nusa Tenggara Timur, Indonesia, (-8.6114819, 120.4619882, 0.0)),
#  'Améria Latina': Location(América Latina, 50404, Santa Clara, Villa Clara, Cuba, (22.3951605, -79.9721028, 0.0)),
#  'STREET DIVISION VA': Location(Division Street, S0N 2V0, Vanguard, Saskatchewan, Canada, (49.907695, -107.301725, 0.0)),
#  'わびさび': Location(びゅうフォレスト喜連川, さくら市, 栃木県, 日本, (36.7471051, 140.0116632486647, 0.0)),
#  'Prolink': Location(Prolink, Kotta Lane, 00800, Kotta Lane, Colombo, Western Province, ශ්‍රී ලංකාව இலங்கை, (6.9110867, 79.8863614, 0.0)),
#  'on ma podium ': Location(Claridge Plaza podium, Rideau Street, K1N 5X8, Rideau Street, Ottawa, Ontario, Canada, (45.427436650000004, -75.68788280168286, 0.0)),
#  'Cebu city , central visayas': Location(Cebu City, Central Visayas, Philippines, (10.2931062, 123.9020773, 0.0)),
#  'Kolkata-700029 , WB , India ': Location(The Oberoi Grand, Chowringhee Place, 700001, Chowringhee Place, Kolkata, West Bengal, India, (22.5614443, 88.35127754824683, 0.0)),
#  'Florida, Panhandle': Location(Panhandle Lane, Florida, United States, (30.775824, -85.703409, 0.0)),
#  'Leadia Campus': Location(Leadership Learning Academy - Layton Campus, West 2675 North, 84041, West 2675 North, Layton, UT, United States, (41.09957035, -111.9669218801465, 0.0)),
#  'From Uganda to Mogadishu': Location(From Kumi to Serere via Ngora, Ngora, Ngora, Uganda, (1.4599035, 33.7562529, 0.0)),
#  'South of the Sun': Location(Sunlands, 5322, South Australia, Australia, (-34.1384847, 139.8805842, 0.0)),
#  'Meu Mundinho': Location(Rua Mundinho Melo, 59615-035, Mossoró, Rio Grande do Norte, Brasil, (-5.1568371, -37.350612, 0.0)),
#  '   india   karnataka   shimoga': Location(Shimoga District, Karnataka, India, (14.0558284, 75.13125339938858, 0.0)),
#  'Hospital Ángeles Pedregal D.F.': Location(Hospital Ángeles del Pedregal, Boulevard Adolfo López Mateos, 10700, Boulevard Adolfo López Mateos, Ciudad de México, México, (19.3119523, -99.22085857971558, 0.0)),
#  'Dumfriesshire': Location(Dumfriesshire, DG1 3NQ, Alba / Scotland, United Kingdom, (55.166667, -3.5, 0.0)),
#  'Tublay ,Benguet': Location(Tublay, 2601, Benguet, Philippines, (16.4751903, 120.6329609, 0.0)),
#  'Berlin, CT': Location(Robin Ct, 44610, Berlin, Ohio, United States, (40.5554149, -81.8087624, 0.0)),
#  'Baybay leyte': Location(Baybay, 6521, Leyte, Philippines, (10.6777771, 124.7977452, 0.0)),
#  "In God's hands :) ": Location(In Gods Hands Lane, 29360, South Carolina, United States, (34.5999736, -81.9552746, 0.0)),
#  'Het Brabantse land ': Location(Brabantse Heide, 1500, België / Belgique / Belgien, (50.7125204, 4.290998784739972, 0.0)),
#  'Somewhere praying 4 revolution': None,
#  'RDC, Kinshasa': Location(République démocratique du Congo, République démocratique du Congo, (-2.9814344, 23.8222636, 0.0)),
#  'philliphines mindanao': Location(Mindanao, Philippines, (7.64784075, 125.17171313357011, 0.0)),
#  'My dreamhouse!': None,
#  '19 Oko Baba Street Ebutte Mett': Location(Oko-Baba Street, 100242, Ebute-Metta, Lagos, Nigeria, (6.4877074, 3.3900976, 0.0)),
#  "mimiw's": Location(Mimiwali Drive, 2450, Coffs Harbour, New South Wales, Australia, (-30.3610059, 153.0672033, 0.0)),
#  'T R I P P Y PH': Location(YSR Nagar Phase-II, 500021, Telangana, India, (17.3007386, 78.5395501, 0.0)),
#  'ÜT: 30.363553,-87.141661': None,
#  'Tichnor, Arkansas': Location(Tichnor, Arkansas, United States, (34.1403791, -91.2706738, 0.0)),
#  'Rosemary Beach ': Location(Rosemary Beach, 49106, Lake Charter Township, Michigan, United States, (41.9819869, -86.5636331, 0.0)),
#  'Kentucky First Congressional District': Location(Conressional Office First District, Pajarito, 6709, Pajarito, Calbayog, Samar, Philippines, (12.0674443, 124.5949155, 0.0)),
#  'U.K.🇬🇧': Location(United Kingdom, United Kingdom, (54.7023545, -3.2765753, 0.0)),
#  'LAHORE': Location(لاہور, 54010, پنجاب, پاکستان, (31.5656822, 74.3141829, 0.0)),
#  'Estenbol': Location(Sønder Esterbølle, Nordfyns Kommune, Region Syddanmark, Danmark, (55.494178149999996, 10.153238020739341, 0.0)),
#  'the medium place': Location(Place Théodore Rivière, Place Théodore Rivière, 75016, Place Théodore Rivière, Paris, Île-de-France, France, (48.8472676, 2.2685969, 0.0)),
#  'Pineville, KY 40977': Location(Ky-Va Stone Road, 40977, Pineville, Kentucky, United States, (36.766329, -83.68454, 0.0)),
#  'Westfarms Mall Farmington CT ': None,
#  'Tea Party, The United States': Location(Mad Tea Party, Seven Seas Drive, 32830, Seven Seas Drive, FL, United States, (28.41998265, -81.57975372651353, 0.0)),
#  'Federal Capital Territory, N': Location(Federal Capital Territory, Nigeria, (8.8311228, 7.1724673, 0.0)),
#  'Tiny Island in the Pacific': Location(Tinian International Airport, 8th Avenue, 96952, 8th Avenue, San Jose, Northern Mariana Islands, United States, (14.99833865, 145.6183628291265, 0.0)),
#  'The Moon 🌒': Location(Temple of the Moon, United States, (38.4459759, -111.1914209, 0.0)),
#  'West Hazleton,PA': Location(West Hazleton Plaza, Diana Lane, 18202, Diana Lane, West Hazleton, PA, United States, (40.968171850000004, -76.00761523949353, 0.0)),
#  'Praia Grande/São Paulo': Location(Praia Grande, São Paulo, Brasil, (-24.005833, -46.402778, 0.0)),
#  'CEU-MANILA': Location(Manilas, Vianí, Cundinamarca, Colombia, (4.9449225, -74.5553805, 0.0)),
#  'Headquarter: Arusha, Dar  ': Location(ExxonMobil World Headquarters, Las Colinas Boulevard, 75039, Las Colinas Boulevard, Irving, Texas, United States, (32.88995425, -96.94992226993453, 0.0)),
#  'New Castle, IN': Location(New Castle, 47362, Indiana, United States, (39.9289351, -85.3702477, 0.0)),
#  'Manila/QuezonCity-Philippines': Location(Manila, Metro Manila, Philippines, (14.5948914, 120.9782618, 0.0)),
#  '#MyHouse UK ,Birmingham ': Location(Birmingham Age UK, High Street, B17 9PP, High Street, Birmingham, England, United Kingdom, (52.4594522, -1.9474166, 0.0)),
#  'Fourth planet from Sol': None,
#  'East of Jhb': Location(Jhābua, State of Madhya Pradesh, India, (22.8750396, 74.7128601, 0.0)),
#  'under His shadow..': Location(Shadowbrook, 29733, Rock Hill, South Carolina, United States, (34.9551449, -81.0284112, 0.0)),
#  'doesnt matter': Location(Doesn't Matter Park, United States, (45.72315235, -94.47015604681278, 0.0)),
#  'col❤️\u200d🩹': Location(Colombia, Colombia, (4.099917, -72.9088133, 0.0)),
#  'snottsdale': None,
#  'In My Nightmares ': Location(Mysuru, 570001, Karnataka, India, (12.3051828, 76.6553609, 0.0)),
#  'Douglas': Location(Douglas, Illinois, United States, (39.7628415, -88.2170516, 0.0)),
#  'repulse bay beach hongkong': Location(淺水灣海灘 Repulse Bay Beach, 淺水灣道 Repulse Bay Road, 淺水灣道 Repulse Bay Road, 香港 Hong Kong, 香港 Hong Kong, 中国, (22.2385434, 114.1951849, 0.0)),
#  'Fibonacci Island': Location(fibonacci, Plaça de Frederic Chopin, 07001, Plaça de Frederic Chopin, Palma, Illes Balears, España, (39.5706024, 2.6482094, 0.0)),
#  'Heanor': Location(Heanor, DE75 7EX, Amber Valley, England, United Kingdom, (53.0145821, -1.3574966, 0.0)),
#  'Present in 40 countries': Location(Old Presentation Convent High School, 403600, Margao, Goa, India, (15.280767, 73.958437, 0.0)),
#  'Laundromat Disco ': Location(Discount Laundromat, Raglan Street, 2024, Raglan Street, Manukau, Auckland, New Zealand / Aotearoa, (-36.9743901, 174.8285776, 0.0)),
#  'Vitoria da conquista': Location(Vitória da Conquista, Bahia, Brasil, (-14.8567487, -40.8414804, 0.0)),
#  'Germany, Saarland': Location(Saarland, Deutschland, (49.3841872, 6.9537369, 0.0)),
#  'She/her ace 27': Location(Hertswood Academy, Cowley Hill, WD6 5LG, Cowley Hill, Borehamwood, England, United Kingdom, (51.6683569, -0.2649151354679794, 0.0)),
#  'ENUGU STATE| SOUTHEAST NIGERIA': Location(Southeast Peoples Development Association, Abakaliki Road, 400261, Abakaliki Road, Enugu, Enugu, Nigeria, (6.461066, 7.502751, 0.0)),
#  'Giddings tx.': Location(Giddings-Lee County Airport, County Road 206, County Road 206, TX, United States, (30.17006255, -96.97940583301542, 0.0)),
#  'Putney - London': Location(Putney, SW15 1RG, London, England, United Kingdom, (51.4625524, -0.2167462, 0.0)),
#  "Director's box!\n": Location(Director's  office, PO Box No 18, Chandrabani, 248001, PO Box No 18, Chandrabani, Dehradun, Uttarakhand, India, (30.28327985, 77.9741849839958, 0.0)),
#  'Whittier, ca': Location(Whittier, California, United States, (33.9708782, -118.030839, 0.0)),
#  'Philippines , Davao': Location(Davao City, Davao Region, Philippines, (7.0648306, 125.6080623, 0.0)),
#  'NO DM’A': Location(DMAXX Garment, No – 75 D, Nugawela, Nugawela, Kandy, Central Province, ශ්‍රී ලංකාව இலங்கை, (7.3276785, 80.5922601, 0.0)),
#  'Land of Garigal & Caregal mob': None,
#  'Made in USSR!': Location(Ussita, Marche, Italia, (42.9437596, 13.137908, 0.0)),
#  'The Netherlands / Ethiopia': Location(ኢትዮጵያ, (10.9380147, 35.22332590030422, 0.0)),
#  "Lyca's": Location(Lycan, Colorado, United States, (37.6155884, -102.200707, 0.0)),
#  'New York/Houston, USA': Location(East Houston Street, 10002, New York, New York, United States, (40.7240975, -73.9927155, 0.0)),
#  'São Paulo,BrasiL': Location(São Paulo, São Paulo, Brasil, (-23.5506507, -46.6333824, 0.0)),
#  'Phil manila': Location(Manila, Metro Manila, Philippines, (14.5948914, 120.9782618, 0.0)),
#  'Englewood, Chicago': Location(Welcome to Englewood, West 63rd Street, 60636, West 63rd Street, Chicago, IL, United States, (41.780088, -87.6319996, 0.0)),
#  'carrefour': Location(Carrefour, Carrer del Xaloc, 08398, Carrer del Xaloc, Santa Susanna, Catalunya, España, (41.63536175, 2.7124396863764, 0.0)),
#  'Sydväst om byn vid Örkelljunga': None,
#  'ABIAS CBN': Location(CBTA No.174, Carretera Irapuato-San Cristóbal-Rancho Nuevo de la Cruz, 36980, Carretera Irapuato-San Cristóbal-Rancho Nuevo de la Cruz, Abasolo, Guanajuato, México, (20.650054599999997, -101.50309351803267, 0.0)),
#  'Campo Grande rj': Location(Pátio CDD Campo Grande-RJ, 26262-020, Rio de Janeiro, Rio de Janeiro, Brasil, (-22.8617922, -43.604283, 0.0)),
#  'www.hackafrica.blogspot.com': None,
#  "N 39°11' 0'' / W 119°46' 0''": Location(119, Point View Parkway, 07470, Point View Parkway, Wayne, NJ, United States, (40.98183995, -74.23302470632987, 0.0)),
#  'Kinshasa(Tshangu/Pascal)': Location(Tshangu, Kinshasa, République démocratique du Congo, (-4.3907327, 15.389717268819188, 0.0)),
#  'Some Where': Location(Some Where, 34 Street, 34 Street, Deira, دبي, الإمارات العربية المتحدة, (25.25393445, 55.329532252504194, 0.0)),
#  'Lafayette Ga': Location(Galerie Lafayette, Q, 84000, Q, Avignon, Provence-Alpes-Côte d'Azur, France, (43.928081, 4.837767, 0.0)),
#  '-22.81308,-43.070462': None,
#  'Cape Town / South Africa': Location(Cape Town, 8001, Western Cape, South Africa, (-33.928992, 18.417396, 0.0)),
#  'sabelas': Location(Le Sabelas, 34600, Bédarieux, Occitanie, France, (43.6070732, 3.189294, 0.0)),
#  'ya mamas house': Location(Mamardub, Guna Yala, Panamá, (9.4526972, -78.8329715, 0.0)),
#  'Where politics happen': Location(De Happerij, Wheemerstraat, 7161 AP, Wheemerstraat, Neede, Gelderland, Nederland, (52.1324954, 6.6170232, 0.0)),
#  'Jhapa ': Location(झापा जिल्ला, कोशी प्रदेश, Nepal, (26.583735400000002, 87.88570103314731, 0.0)),
#  'Travelling the world/ follow ': None,
#  'Fla,VA.NC.TN. TX.Cal.NV.GA.NYC': None,
#  'London Essex': Location(Essex Road, Canonbury Road, N1 8LZ, Canonbury Road, London, England, United Kingdom, (51.5407328, -0.0961859, 0.0)),
#  'I Follow Everybody': Location(Follonica, 58022, Toscana, Italia, (42.926326, 10.761625, 0.0)),
#  'FURAHA APARTMENTS, UNIT 5 OFF ': Location(Office Park Road, 50265, West Des Moines, Iowa, United States, (41.5912097, -93.7209774, 0.0)),
#  "my husband's house 😘": Location(My home, house 2, Street 2, 56300, Street 2, اوکاڑہ, پنجاب, پاکستان, (30.7958553, 73.4333575, 0.0)),
#  'probably lost ': None,
# ...
#  'Wherever Luis is ❤️❤️': Location(Isla Luisa, Chile, (-55.0369179, -70.409082302048, 0.0)),
#  'North West of Moscow': Location(West Moscow Road, 53516, Town of Moscow, Wisconsin, United States, (42.8317501, -89.8555632, 0.0)),
#  'Laguna de Duero, Valladolid': Location(Laguna de Duero, 47140, Castilla y León, España, (41.582811, -4.7214404, 0.0)),
#  'Matutina -Minas Gerais, Brasil': Location(Matutina, Minas Gerais, Brasil, (-19.221956, -45.9701654, 0.0)),
#  'Mouzaia                       ': Location(Mouzaia, 09210, Blida البليدة, Algérie / ⵍⵣⵣⴰⵢⴻⵔ / الجزائر, (36.4674416, 2.6879953, 0.0)),
#  'Dagupan City , Philippines': Location(Dagupan City Park, 2400, Philippines, (16.04318125, 120.3341894658141, 0.0)),
#  'Yeovil "Its A dry town"  ': Location(Tornante 9 Antonella, 38704, Drena, Trentino-Alto Adige/Südtirol, Italia, (45.9502363, 10.962175, 0.0)),
#  'hattersley hyde manchester': Location(Hyde Road, SK14 6PW, Tameside, England, United Kingdom, (53.4550243, -2.0226011, 0.0)),
#  'Italy - Bg-Bl-Bz': None,
#  'India, Odisha': Location(Odisha, India, (20.5431241, 84.6897321, 0.0)),
#  'Koronadal city': Location(Koronadal City Public Cemetry, Philippines, (6.4964908999999995, 124.83497890829403, 0.0)),
#  'guarulhos ': Location(Guarulhos, São Paulo, Brasil, (-23.4428948, -46.5243855, 0.0)),
#  '28.0046° S, 26.7732° E': Location(El 26, 00642, Comerío, Puerto Rico, United States, (18.2275814, -66.2188563, 0.0)),
#  'Sacramento.': Location(Sacramento, California, United States, (38.5810606, -121.493895, 0.0)),
#  'tecuci': Location(Tecuci, România, (45.8457816, 27.4290798, 0.0)),
#  'TWitter UaE/Philippines': Location(Uala Island, Philippines, (14.922003, 122.1839889, 0.0)),
#  'Raising Cane in #Missouri ;)b': Location(Raising Cane's, Starlight Drive, 64012, Starlight Drive, Belton, Missouri, United States, (38.8129897, -94.5101398, 0.0)),
#  'co cork': Location(Cork, Éire / Ireland, (51.897077, -8.4654674, 0.0)),
#  'iLiveWhereYouVacation FL ': None,
#  'virgin paradise': Location(Paradise, West Virginia, United States, (38.5848113, -81.7998539, 0.0)),
#  '⏬詳しくはここをクリック❣️': None,
#  'Venezolano-canadience (Canadá)': Location(Agence spatiale canadienne, Boulevard Clairevue Ouest, J3V 6E6, Boulevard Clairevue Ouest, Longueuil, Québec, Canada, (45.519769, -73.39358108339738, 0.0)),
#  'jagityal': Location(Jagityal_Rural mandal, Telangana, India, (18.8249636, 78.87883315938271, 0.0)),
#  'mexico\n': Location(México, México, (23.6585116, -102.0077097, 0.0)),
#  'South Banks': Location(Bankstown, 2200, Canterbury-Bankstown Council, New South Wales, Australia, (-33.9171897, 151.0335881, 0.0)),
#  'madrd españa': Location(Avenida Madrd, 10, Avenida de Madrid, 03610, Avenida de Madrid, Petrer, Comunitat Valenciana, España, (38.4785271, -0.784417, 0.0)),
#  'Web3 resources 👉': Location(Resource Drive, Laredo, Texas, United States, (27.6810154, -99.4523391, 0.0)),
#  "N 14°6' 0'' / E 78°9' 0''": Location(50°51'48.4"N 14°00'28.9"E, 01816, Deutschland, (50.8632741, 14.0078331, 0.0)),
#  'chihuahua chihuahua': Location(Chihuahua, México, (28.5000001, -106.0000001, 0.0)),
#  'East TN ': Location(Tniumanu, Nusa Tenggara Timur, Indonesia, (-9.4813123, 124.8290537, 0.0)),
#  "Dreamin'": Location(Dreaming Creek, 24502, United States, (37.3411557, -79.2296317, 0.0)),
#  'Not where there are mountains': None,
#  'M.di Campiglio-Trento-Italy': Location(Madonna di Campiglio, 38084, Pinzolo, Trentino-Alto Adige/Südtirol, Italia, (46.2269942, 10.8270157, 0.0)),
#  'Queretaro; Qro': Location(Los Cues- Santa Teresa- QRO 400, 76976, Los Cues, Querétaro, México, (20.5080847, -100.2851944, 0.0)),
#  'beard oil @': Location(Rue des Oeillets, J0P 1R0, Rivière-Beaudette, Québec, Canada, (45.2450865, -74.3297948, 0.0)),
#  'Evans City, PA': Location(Evans City Park, United States, (40.373715, -104.689601490261, 0.0)),
#  'Donje Brijanje': Location(Доње Бријање, Централна Србија, Србија, (43.100542, 21.817226, 0.0)),
#  'The new south': Location(The University of Sydney, Campbell Street, 2006, Campbell Street, camperdown, New South Wales, Australia, (-33.88888125, 151.18941425705117, 0.0)),
#  'puerto rico ': Location(Puerto Rico, United States, (18.2247706, -66.4858295, 0.0)),
#  'Humacao P.R.': Location(Humacao, Puerto Rico, United States, (18.1491849, -65.8250136, 0.0)),
#  'Atraulia': Location(Atraulia, 223223, Uttar Pradesh, India, (26.3337222, 82.9473843, 0.0)),
#  'Bruxelles - Douala': Location(Auto-école Bruxelles, bloc E, bloc E, Douala V, Littoral, Cameroun, (4.0778666, 9.749994674431377, 0.0)),
#  'βυғғαℓø': None,
#  'Bomet mogor labotyet kenya ': Location(Mogogosiek Health Centre, Bomet, Kenya, (-0.61503655, 35.26337035, 0.0)),
#  'BUSTER': Location(Buster Island, United States, (27.9314113, -81.3667381, 0.0)),
#  'Piramagrun , Slemani-Kurdistan': Location(Piramagrun Street, 46001, سلێمانی, پارێزگای سلێمانی, العراق, (35.5685121, 45.4146652, 0.0)),
#  'Las pi': Location(Las Piedras, 90200, Canelones, Uruguay, (-34.7274904, -56.2164982, 0.0)),
#  'Nigeria,Lagos,s/lere': Location(Surulere, 101212, Oke Ira, Lagos, Nigeria, (6.5024582, 3.3590279, 0.0)),
#  'Newark, Delaware 19711': Location(Delaware Circle, 19711, Newark, Delaware, United States, (39.6821289, -75.7395211, 0.0)),
#  'Global City, Taguig': Location(St. Luke's Medical Center Global City, 32nd Street, 1634, 32nd Street, Taguig, Metro Manila, Philippines, (14.555140900000001, 121.04813809093798, 0.0)),
#  '1D and bieber land': Location(Andelfingen, Langenenslingen, Baden-Württemberg, Deutschland, (48.153565, 9.411618258463434, 0.0)),
#  'LUBUMBASHI (RDC)': Location(Boulevard RDC, Munua, Haut-Katanga, République démocratique du Congo, (-11.6195377, 27.4266192, 0.0)),
#  ' اللهم اشغلني بما خلقتني له': None,
#  'すみっこ': None,
#  'Far far away with Shrek': None,
#  'Nasug': Location(Nasugbu, 4231, Batangas, Philippines, (14.0734578, 120.6322736, 0.0)),
#  'The GC, ID': Location(Thekkady, 685536, Idukki, Kerala, India, (9.5804995, 77.181142, 0.0)),
#  'Sa, mars': Location(Marseille, 13000, Provence-Alpes-Côte d'Azur, France, (43.2961743, 5.3699525, 0.0)),
#  'Fłórïðã': Location(Florida, United States, (27.7567667, -81.4639835, 0.0)),
#  'Gloucester/ Hayes': Location(Hayes, 23072, Gloucester Point, Virginia, United States, (37.2781992, -76.5038395, 0.0)),
#  '충북 제천시 청풍호': Location(청풍중학교, 청풍호로, 27212, 청풍호로, 충청북도 제천시 청풍면, 충청북도, 대한민국, (36.9962642, 128.165439, 0.0)),
#  'Miami Beach(Port of Miami)': Location(Port of Miami, Miami, Florida, United States, (25.7735142, -80.16919616513563, 0.0)),
#  'hive': Location(Hive Island, United States, (59.884417400000004, -149.37331080247253, 0.0)),
#  'Make more money': Location(Moneydorragh More, Northern Ireland, United Kingdom, (54.11521725, -5.929051058478382, 0.0)),
#  'Misurata , libya ♥️': Location(Misurata free zone, بني وليد, ليبيا, (32.35112865, 15.20605878479635, 0.0)),
#  'Brentford, UK': Location(HSBC UK, High Street, CM14 4RH, High Street, Brentwood, England, United Kingdom, (51.6201147, 0.3006116, 0.0)),
#  'Leyland | South Ribble | Lancs': Location(Leyland, PR25 2EX, South Ribble, England, United Kingdom, (53.6904813, -2.6991336, 0.0)),
#  'Alcala, Cagayan, Philippines': Location(Alcala, 3507, Cagayan, Philippines, (17.9024399, 121.6541034, 0.0)),
#  'in da cookie monster': Location(Cookies corner, 403802, Vasco da Gama, Goa, India, (15.3895032, 73.8163845, 0.0)),
#  'atlantic city ✈ jamaica ': Location(Atlantic City, 08401, New Jersey, United States, (39.3642852, -74.4229351, 0.0)),
#  'ZAMBOANGA CITY': Location(Zamboanga City, 7000, Zamboanga Peninsula, Philippines, (6.9046909, 122.076462, 0.0)),
#  'College park': Location(University of Maryland, College Park, Diamondback Drive, 20742, Diamondback Drive, College Park, Maryland, United States, (38.990412449999994, -76.9438585924238, 0.0)),
#  'Right Down the Street': Location(The Right Light, South Sharp Street, 21230, South Sharp Street, Baltimore, MD, United States, (39.2851782, -76.6175972, 0.0)),
#  'Mengcun, Hebei, China': Location(孟村县, 061000, 沧州市, 河北省, 中国, (38.052498, 117.0981778, 0.0)),
#  'WINNER CITY': Location(Winner City Park, United States, (43.3749142, -99.86739435375304, 0.0)),
#  'matati city': Location(Matatiro Street, 5022, Porirua, Wellington, New Zealand / Aotearoa, (-41.1110313, 174.8343514, 0.0)),
#  'The Beloved Community': Location(Beloved Community Park, United States, (33.579754199999996, -85.0736900470259, 0.0)),
#  'Toloso Tx.': Location(Txingurri bailara, 20494, Hernialde, Euskadi, España, (43.1578383, -2.0842787, 0.0)),
#  'ÜT: 54.960465,-1.51521': None,
#  'Adelfia, Bari, Italy': Location(Adelfia, Puglia, Italia, (41.0042654, 16.8716526, 0.0)),
#  "Children's Omaha": Location(Omaha Childrens Museum, Howard Street, 68102, Howard Street, Omaha, NE, United States, (41.2549986, -95.94307, 0.0)),
#  'Poro, Camotes, Cebu': Location(Camotes Circumferential Road, Poro, Cebu, Philippines, (10.6281225, 124.4338533, 0.0)),
#  'Monrovia Liberia🇱🇷': Location(Monrovia, Montserrado, Liberia, (6.328034, -10.797788, 0.0)),
#  'Gangapur City, India': Location(Gangapur City, Nasiya colony, 322200, Nasiya colony, gangapur city, Rajasthan, India, (26.4681809, 76.7266811, 0.0)),
#  'Lindo Parque, São Gonçalo': Location(Lindo Parque I, São Gonçalo, Rio de Janeiro, Brasil, (-22.8338, -43.0549, 0.0)),
#  'power full no sarawak ': Location(Sibu Full Gospel Church, NO 2, Lorong Delta 1, 96000, Lorong Delta 1, SIBU, Sarawak, Malaysia, (2.3056576, 111.8271863, 0.0)),
#  'Bacooor Cavite': Location(Bacoor, 4102, Cavite, Philippines, (14.458816, 120.959579, 0.0)),
#  'Juazeiro do Norte-CE ': Location(Juazeiro do Norte, Ceará, Brasil, (-7.2153453, -39.3153336, 0.0)),
#  'In a fairly big city': Location(Fairley Street, G51 2SN, Glasgow, Alba / Scotland, United Kingdom, (55.8532827, -4.302979, 0.0)),
#  'Where I am at.': Location(Where-It's-at Road, Idaho, United States, (48.021099, -116.801576, 0.0)),
#  'Atlanta, 🇺🇸/Guildford, 🇬🇧': Location(Atlanta Street, 27406, Greensboro, North Carolina, United States, (36.039926, -79.807188, 0.0)),
#  'Price County, WI': Location(Price, Wisconsin, United States, (45.676627, -90.368792, 0.0)),
#  'cyrus ': Location(Cyrus, Minnesota, United States, (45.614683, -95.738103, 0.0)),
#  'Houthulst, België': Location(Houthulst, 8650, Houthulst, West-Vlaanderen, België / Belgique / Belgien, (50.973812249999995, 2.943856800994059, 0.0)),
#  'The Head of the Class': Location(Head of the Class Jerk Centre, Jamaica, (17.9367169, -77.17288705, 0.0)),
#  'Ossett, Wakefield': Location(Ossett, WF5 8AQ, Wakefield, England, United Kingdom, (53.6780539, -1.5765949, 0.0)),
#  'somewhere Far, Far Away.': Location(فەرەجاوا, پارێزگای سلێمانی, العراق, (35.4684419, 45.482669, 0.0)),
#  'Safe zone': Location(SAFE ZONE, 2500, België / Belgique / Belgien, (51.0831431, 4.5674295284343245, 0.0)),
#  'Santa Clarita, CA, USA': Location(Santa Clarita, California, United States, (34.3916641, -118.542586, 0.0)),
#  'Dhanbab ': Location(Dhanbad, 826001, Jharkhand, India, (23.7952809, 86.4309638, 0.0)),
#  'bremen, germany': Location(Bremen, Freie Hansestadt Bremen, Deutschland, (53.0758196, 8.8071646, 0.0)),
#  '𝙺𝚊𝚒🤍': None,
#  'Instagram: @jaumenolla': None,
#  'Hanwara': Location(Hanwāra, Jharkhand, India, (25.0809031, 87.2218215, 0.0)),
#  'North of C&D Canal': Location(El Cañal, 72400, Municipality of Siuna, Región Autónoma de la Costa Caribe Norte, Nicaragua, (13.4992061, -85.0993681, 0.0)),
#  'अखण्ड भारतवर्ष': None,
#  'Aleutian Islands': Location(Aleutian Islands, United States, (54.720894799999996, -164.04086621161764, 0.0)),
#  'satan house ': Location(SAtanton House, Beacon View Road, B71 3PW, Beacon View Road, West Bromwich, England, United Kingdom, (52.54801575, -1.9732398790085082, 0.0)),
#  'Milton of Campsie': Location(Milton of Campsie, G66 8BU, Alba / Scotland, United Kingdom, (55.962501, -4.1617181, 0.0)),
#  'waves on the sea': Location(St Annes-on-the-Sea, Station Yard, FY8 2JE, Station Yard, Fylde, England, United Kingdom, (53.7531813, -3.02895, 0.0)),
#  '岡山 勝央町': None,
#  'トイレorフトン': None,
#  "Tiffany's": Location(Tiffany, St. Louis, Missouri, United States, (38.6211367, -90.2417152, 0.0)),
#  'Baton Rouge \tLouisiana ': Location(Baton Rouge, Louisiana, United States, (30.4507936, -91.1391153, 0.0)),
#  'Shimo la Tewa': Location(Shimo La Tewa, Laini Saba, Nairobi, Kenya, (-1.31153125, 36.79358953426245, 0.0)),
#  'Miami based, Work Everywhere': None,
#  "Habitbi's": Location(Constructeur Maisons Habitbois, Rue de Fontenay, 51470, Rue de Fontenay, Saint-Memmie, Grand Est, France, (48.9515674, 4.389864626111506, 0.0)),
#  'Lagos | Awka': Location(Awka Ekiti Street, 071639, Lagos, Nigeria, (6.4949712, 3.3065018, 0.0)),
#  'On clouds above PortArthur-Tx ': None,
#  'Burbank, └A, California USA 🇺🇸🇺🇸🇺🇸\u200b': Location(Burbank, California, United States, (34.1816482, -118.3258554, 0.0)),
#  'Alvin Texas, USA': Location(Murphy USA, 77578, Alvin, Texas, United States, (29.42375045, -95.23012385, 0.0)),
#  'MB Kalanganan Cotabato City': None,
#  'Police State, North America': Location(American Canyon Police Department, 911 Donaldson Way E, 94503, 911 Donaldson Way E, American Canyon, California, United States, (38.1718505, -122.2484056, 0.0)),
#  'Somewhere, Illinois': None,
#  'Motse Moholo Maseru': Location(Ha Moholobela, Lesotho, (-29.5063674, 28.0622631, 0.0)),
#  'My Kingdom': Location(Mynytho, LL53 7ST, Cymru / Wales, United Kingdom, (52.8476971, -4.5230986, 0.0)),
#  'Santa Marta de Tormes, Spain': Location(Santa Marta de Tormes, Castilla y León, España, (40.9492102, -5.6306215, 0.0)),
#  'Feliz al lado de mi esposito!!': Location(San Miguel La Labor, Estado de México, México, (19.6075312, -99.9989111, 0.0)),
#  'A casa mia.': Location(Casa Mia, 89A, Yorckstraße, 10965, Yorckstraße, Berlin, Deutschland, (52.4928419, 13.3864776, 0.0)),
#  'Caledonia, NY': Location(Nygrens Road, 05867, Sutton, Vermont, United States, (44.684104, -72.011628, 0.0)),
#  'Cebu City, Visayas': Location(Cebu City, Central Visayas, Philippines, (10.2931062, 123.9020773, 0.0)),
#  'Oss & Nijmegen': Location(Ossenwaard, 6541 GE, Nijmegen, Gelderland, Nederland, (51.859097, 5.8456026, 0.0)),
#  'banyoles': Location(Banyoles, 17820, Catalunya, España, (42.1180477, 2.7653607, 0.0)),
#  'FarRock.The Bx.Atl. ': Location(Atherstone Mews, SW7 5BX, London, England, United Kingdom, (51.4955086, -0.1823527, 0.0)),
#  'luyo sa cebudok ~': Location(San Jose de Luyo, Chavín, Ica, Perú, (-13.0554522, -75.8972588, 0.0)),
#  'South Florida, U.S.A.': Location(Florida Southern College, Lake Hollingsworth Drive, 33081, Lake Hollingsworth Drive, Lakeland, Florida, United States, (28.030456100000002, -81.94554251154706, 0.0)),
#  'Philippines Ph QC, sanbartolome ACF homes 41 virgo st,': Location(Accacia Street, 4103, Imus, Cavite, Philippines, (14.3842539, 120.9424485, 0.0)),
#  'Land of Logic, USA': Location(Chemin de l'Usage, 40660, Messanges, Nouvelle-Aquitaine, France, (43.7972762, -1.3661989, 0.0)),
#  '@gildedheartt ': None,
#  'Colombia-Bogota ': Location(Bogotá, Colombia, (4.6534649, -74.0836453, 0.0)),
#  "In my mom's garage": Location(Mobibrasil S.A - Garagem Alvarenga, Estrada do Alvarenga, Estrada do Alvarenga, São Paulo, São Paulo, Brasil, (-23.70386405, -46.645749690536476, 0.0)),
#  'PA Congressional District 13': Location(13 Circular Road, 13, 13 Circular Road, 800001, 13 Circular Road, Patna, Bihar, India, (25.598567350000003, 85.10477896742285, 0.0)),
#  'Freedom Way': Location(Freedom Way, 46818, Fort Wayne, Indiana, United States, (41.1491644, -85.1811739, 0.0)),
#  'where no light can be seen': Location(Belle Isle Northeast Light, Newfoundland and Labrador, Canada, (52.01357695, -55.280304241901405, 0.0)),
#  'Minembwe, Democratic Republic ': Location(Minembwe, Sud-Kivu, République démocratique du Congo, (-3.9344201, 28.7300599, 0.0)),
#  'A Lubumbashi': Location(Lubumbashi International Airport, Avenue Luano, Avenue Luano, Luano, Haut-Katanga, République démocratique du Congo, (-11.5907528, 27.527636755291578, 0.0)),
#  'sukabumi, indonesia': Location(Sukabumi, Jawa Barat, Indonesia, (-6.9199289, 106.9265095, 0.0)),
#  '011': Location(011, ދިވެހިރާއްޖެ, (6.5488705, 72.94983892512292, 0.0)),
#  ...}

# %%
# save data
with open(os.path.join(DATA_PATH, 'resolved.pkl'), 'wb+') as f:
    pickle.dump(resolved, f)
with open(os.path.join(DATA_PATH, 'tested.pkl'), 'wb+') as f:
    pickle.dump(tested, f)
with open(os.path.join(DATA_PATH, 'timed_out.pkl'), 'wb+') as f:
    pickle.dump(timed_out, f)
with open(os.path.join(DATA_PATH, 'excepted.pkl'), 'wb+') as f:
    pickle.dump(excepted, f)

# %%
resolved

# %%
len(timed_out)

# %%
resolved_reverse = dict()
tested_reverse = set()
timed_out_reverse = set()

# %%
location_obj.raw
# Out:
# Location(La Jolie Vallée, Route de Moras Le Village, 38460, Route de Moras Le Village, Veyssilieu, Auvergne-Rhône-Alpes, France, (45.6806461, 5.2195177, 0.0))

# %%
for location, location_obj in tqdm(resolved.items()):
    if location in tested_reverse:
        continue
    if not location_obj:
        continue
    try:
        resolved_reverse[location] = reverse_location(location_obj, geolocator)
    except GeocoderTimedOut as e:
        timed_out_reverse.add(location)
    finally:
        tested_reverse.add(location)

# save data
# with open(os.path.join(DATA_PATH, 'resolved_reverse.pkl'), 'wb+') as f:
#     pickle.dump(resolved_reverse, f)
# with open(os.path.join(DATA_PATH, 'tested_reverse.pkl'), 'wb+') as f:
#     pickle.dump(tested_reverse, f)
# with open(os.path.join(DATA_PATH, 'timed_out_reverse.pkl'), 'wb+') as f:
#     pickle.dump(timed_out_reverse, f)
# Out:
#   0%|          | 0/1118 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 7
#       5     continue
#       6 try:
# ----> 7     resolved_reverse[location] = reverse_location(location_obj, geolocator)
#       8 except GeocoderTimedOut as e:
#       9     timed_out_reverse.add(location)
#
# Cell In[5], line 6, in reverse_location(location_obj, geolocator, **kwargs)
#       4 def reverse_location(location_obj, geolocator, **kwargs):
#       5     try:
# ----> 6         coords = ",".join((location_obj.raw['lat'], location_obj.raw['lon']))
#       7     except AttributeError as e:
#       8         return None
#
# KeyError: 'lat'

# %%
locations['location_obj'] = locations.location_str.map(resolved)

# %%
# # apply the geolocator
# locations['location_obj'] = locations.location_str.apply(partial(get_location, geolocator=geolocator))

# %% [markdown]
# Not everything finds a match on Nominatim, esp. when there are natural language descriptions.
#
# Perhaps we could give it a pass of NER for GEO entities first

# %%
locations[locations.location_obj.isna()]

# %% [markdown]
# The information returned by the `geocode` function is quite limited, because it tries to fit the specific string.
# For example, states are rarely included in the object. Reverse geocoding helps with generalizing in this case.

# %%
locations['location_obj_reversed'] = locations.location_str.map(resolved_reverse)

# %%
# # apply the reverse geolocator
# locations['location_obj_reversed'] = locations.location_obj.apply(partial(reverse_location, geolocator=geolocator))

# %%
# unpack address information
addresses = pd.DataFrame(locations.location_obj_reversed.dropna().apply(lambda x:pd.Series(x.raw['address'])))
addresses.head()
# Out:
#                                      county        state ISO3166-2-lvl4  \
# id
# 1599787232                   Decatur County       Kansas          US-KS
# 1549733678233837568  Greater Bridgeport COG  Connecticut          US-CT
# 1586767903973511168        Riverside County   California          US-CA
# 1578080496906641408            Adams County     Colorado          US-CO
# 1550149641823469568          Decatur County       Kansas          US-KS
#
#                            country country_code  \
# id
# 1599787232           United States           us
# 1549733678233837568  United States           us
# 1586767903973511168  United States           us
# 1578080496906641408  United States           us
# 1550149641823469568  United States           us
#
#                                                    road  \
# id
# 1599787232                                          NaN
# 1549733678233837568  Governor John Davis Lodge Turnpike
# 1586767903973511168                       Kalmia Street
# 1578080496906641408                  Civic Center Drive
# 1550149641823469568                                 NaN
#
#                                       neighbourhood        city postcode  \
# id
# 1599787232                                      NaN         NaN      NaN
# 1549733678233837568  Bassickville Historic District  Bridgeport    06601
# 1586767903973511168                             NaN    Murrieta    92562
# 1578080496906641408                             NaN    Thornton    80229
# 1550149641823469568                             NaN         NaN      NaN
#
#                                    amenity  ... archipelago subward ward  \
# id                                          ...
# 1599787232                             NaN  ...         NaN     NaN  NaN
# 1549733678233837568                    NaN  ...         NaN     NaN  NaN
# 1586767903973511168                    NaN  ...         NaN     NaN  NaN
# 1578080496906641408  Thornton Civic Center  ...         NaN     NaN  NaN
# 1550149641823469568                    NaN  ...         NaN     NaN  NaN
#
#                     square allotments landuse community zone ISO3166-2-lvl10  \
# id
# 1599787232             NaN        NaN     NaN       NaN  NaN             NaN
# 1549733678233837568    NaN        NaN     NaN       NaN  NaN             NaN
# 1586767903973511168    NaN        NaN     NaN       NaN  NaN             NaN
# 1578080496906641408    NaN        NaN     NaN       NaN  NaN             NaN
# 1550149641823469568    NaN        NaN     NaN       NaN  NaN             NaN
#
#                     banner
# id
# 1599787232             NaN
# 1549733678233837568    NaN
# 1586767903973511168    NaN
# 1578080496906641408    NaN
# 1550149641823469568    NaN
#
# [5 rows x 70 columns]

# %%
# merge with the original dataframe
locations = pd.merge(locations, addresses, left_index=True, right_index=True)

# %%
locations[['location_str', 'country_code']]
# Out:
#                             location_str country_code
# id
# 10285                        Orlando, FL           us
# 451943                   Perugia - Italy           it
# 614543                    Biella - Italy           it
# 687203                        London-ish           al
# 785595                     Dallas, Texas           us
# ...                                  ...          ...
# 1613973600650027008           Fresno, CA           us
# 1613993985361727488  Bandung, Jawa Barat           id
# 1614036014535680000                Egypt           eg
# 1614049376480935936                  ATX           kz
# 1614093412499685376    Brasilia, Brasile           br
#
# [21641 rows x 2 columns]

# %% [markdown]
# some errors appear bizarre -- hard to correct

# %%
locations.loc[687203].location_obj.raw
# Out:
# {'place_id': 52010716,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'node',
#  'osm_id': 4602247639,
#  'boundingbox': ['41.3311355', '41.3312355', '19.8173253', '19.8174253'],
#  'lat': '41.3311855',
#  'lon': '19.8173753',
#  'display_name': 'London, Bulevardi Zogu i Parë, Qendra, Njësia Bashkiake Nr. 9, Tiranë, Bashkia Tiranë, Qarku i Tiranës, Shqipëria Qendrore, 1005, Shqipëria',
#  'class': 'amenity',
#  'type': 'cafe',
#  'importance': 0.11000999999999997,
#  'icon': 'https://nominatim.openstreetmap.org/ui/mapicons/food_cafe.p.20.png'}

# %%
def latlong(location_obj):
    try:
        return pd.Series({'lat':location_obj.raw['lat'], 'lon':location_obj.raw['lon']})
    except AttributeError as e:
        return pd.Series({'lat':None, 'lon':None})

locations = pd.merge(locations, locations.location_obj.apply(latlong), left_index=True, right_index=True)

# %%
# save data
os.makedirs(DATA_PATH, exist_ok=True)
locations[['location_str', 'country_code']].to_csv(os.path.join(DATA_PATH, 'bio_country_codes.csv'))
locations[['location_str', 'railway',
           'road', 'suburb', 'borough', 'city', 'ISO3166-2-lvl4', 'postcode',
           'country', 'country_code', 'village', 'municipality', 'county',
           'ISO3166-2-lvl6', 'state', 'region', 'subdistrict', 'house_number',
           'tourism', 'neighbourhood', 'ISO3166-2-lvl8', 'state_district',
           'quarter', 'city_district', 'lat', 'lon']].to_csv(os.path.join(DATA_PATH, 'bio_locations.csv'))
locations.to_pickle(os.path.join(DATA_PATH, 'bio_locations.pkl'))

# %%
locations.groupby('country_code').size().sort_values(ascending=False)
# Out:
# country_code
# us    17169
# gb     2261
# ca     1078
# it      843
# in      821
#       ...
# bt        1
# mc        1
# bz        1
# mg        1
# cv        1
# Length: 177, dtype: int64

# %%
locations[locations.country_code=='us'].groupby('state').size().sort_values(ascending=False)
# Out:
# state
# Georgia                         2986
# Kansas                          2907
# California                      1928
# Florida                         1609
# Massachusetts                    742
# New York                         719
# North Carolina                   361
# New Jersey                       361
# Ohio                             343
# Arizona                          337
# Illinois                         315
# Pennsylvania                     272
# Nevada                           260
# Tennessee                        230
# Michigan                         191
# District of Columbia             182
# Oregon                           164
# Washington                       160
# Indiana                          155
# Virginia                         147
# Missouri                         147
# Colorado                         146
# Utah                             143
# Alabama                          132
# Maryland                         130
# Oklahoma                         130
# Wisconsin                        109
# Kentucky                         107
# Minnesota                        103
# South Carolina                    96
# Arkansas                          62
# Louisiana                         57
# Connecticut                       55
# New Hampshire                     53
# Mississippi                       49
# Idaho                             49
# New Mexico                        47
# Iowa                              45
# Nebraska                          45
# Maine                             44
# North Dakota                      37
# Rhode Island                      35
# West Virginia                     28
# Texas                             28
# Montana                           23
# Hawaii                            23
# Wyoming                           21
# Puerto Rico                       19
# Delaware                          18
# Guam                              14
# Alaska                            13
# South Dakota                      11
# Vermont                            9
# Northern Mariana Islands           4
# United States Virgin Islands       1
# dtype: int64
